# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('eigentable.csv')
df.columns = [i for i in range(50)]
df.shape
# Out:
# (7296, 50)

# %%
df[[i for i in range(5)]].shape
# Out:
# (7296, 5)

# %%
g = sns.PairGrid(df[[i for i in range(5)]])
